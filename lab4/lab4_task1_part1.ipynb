# %%
from random import randrange, random
from collections import Counter
from pathlib import Path

keyboardWords = Path('inFiles/Keyboard.txt').read_text().splitlines()
nameWords = Path('inFiles/names.txt').read_text().splitlines()
words = Path('inFiles/Words.txt').read_text().splitlines()
top100Words = Path('inFiles/top100.txt').read_text().splitlines()
top1mWords = Path('inFiles/top1M.txt').read_text().splitlines()
passWords = Path('outFiles/Passwords.txt').read_text().splitlines()

# перевірка на дублі слів в файлах
print(f'{len(keyboardWords) = }, зайві:', 
    ' '.join(f'{x[0]} /{x[1] - 1}' for x in list(sorted(Counter(keyboardWords)
    .items(), key=lambda x: x[1], reverse=True)) if x[1] > 1) or '')
print(f'{len(nameWords) = }, зайві:', 
    ' '.join(f'{x[0]} /{x[1] - 1}' for x in list(sorted(Counter(nameWords)
    .items(), key=lambda x: x[1], reverse=True)) if x[1] > 1) or '')
print(f'{len(words) = }, зайві:', 
    ' '.join(f'{x[0]} /{x[1] - 1}' for x in list(sorted(Counter(words)
    .items(), key=lambda x: x[1], reverse=True)) if x[1] > 1) or '')
print(f'{len(top100Words) = }, зайві:', 
    ' '.join(f'{x[0]} /{x[1] - 1}' for x in list(sorted(Counter(top100Words)
    .items(), key=lambda x: x[1], reverse=True)) if x[1] > 1) or '')
print(f'{len(top1mWords) = }, зайві:', 
    ' '.join(f'{x[0]} /{x[1] - 1}' for x in list(sorted(Counter(top1mWords)
    .items(), key=lambda x: x[1], reverse=True)) if x[1] > 1) or '')

# print(f'{len(passWords) = }, зайві:', 
#     ' '.join(f'{x[0]} /{x[1] - 1}' for x in list(sorted(Counter(passWords).items(), key=lambda x: x[1], reverse=True)) if x[1] > 1) or '')
# перетворення у множини (залишення унікальних слів)
keyboardWords = set(keyboardWords)
nameWords = set(nameWords)
words = set(words)
top100Words = set(top100Words)
top1mWords = set(top1mWords)
passWords = set(passWords)
# print(len(passWords & top1mWords), len(passWords & top100Words))
# перетворення у списки унікальних слів (дозволять їх індексувати)
keyboardWords = list(keyboardWords)
nameWords = list(nameWords)
words = list(words)
top100Words = list(top100Words)
top1mWords = list(top1mWords)
passWords = list(passWords)
# Out:
# len(keyboardWords) = 20, зайвих: 0
#  []
# len(nameWords) = 21985, зайвих: 2
#  [("O'Hara", 2), ("O'Neill", 2)]
# len(words) = 1526, зайвих: 0
#  []
# len(top1hWords) = 100, зайвих: 1
#  [('123456789', 2)]
# len(top1mWords) = 999998, зайвих: 0
#  []
# len(passWords) = 100000, зайвих: 0
#  []
# 66269 99

# %%
symbols = "!@#$%^&*-_"

def humanLikePassGenerate():
    # варіанти людських паролів
    r = randrange(100)
    if r < 20:
        password = passWithDateOnlyGenerate()
    elif r < 40:
        password = PassWithWordsGenerate()
    elif r < 60:
        password = passWithNameGenerate()
    elif r < 80:
        password = passWithNumberOnlyGenerate()
    else:
        password = passWithKeyPatternGenerate()
    return replaceLettersWithNumbersInPass(password)

def PassWithWordsGenerate():
    # варіанти з словами
    word = words[randrange(len(words))]
    symbol = symbols[randrange(len(symbols))]
    number = f'{randrange(2022)}'
    flag = randrange(125)
    if flag < 25:
        password = word + symbol + number
    elif flag < 50:
        password = number + symbol + word
    elif flag < 75:
        password = number + word
    elif flag < 100:
        password =  word + number 
    else:
        password = word + words[randrange(len(words))]
        if len(password) < 10:
            password+= words[randrange(len(words))]
    password = changeLetterRegisterInPass(password)
    return password

def passWithNameGenerate():
    # варіанти з іменами
    name = nameWords[randrange(len(nameWords))]
    symbol = symbols[randrange(len(symbols))]
    number = f'{randrange(2022)}'
    flag = randrange(100)
    if flag < 25:
        password = name + symbol + number
    elif flag < 50:
        password = number + symbol + name
    elif flag < 75:
        password = number + name
    else:
        password =  name + number
    password = changeLetterRegisterInPass(password)
    return password

def passWithKeyPatternGenerate():
    # варіанти слів, чисел і клавіатурних комбінацій
    keyPattern = keyboardWords[randrange(len(keyboardWords))]
    word = words[randrange(len(words))]
    number = randrange(10000)
    if random() > 0.5:
        password = f'{word}{keyPattern}'
    else:
        password = f'{keyPattern}{number}'
    password = changeLetterRegisterInPass(password)
    return password

def passWithNumberOnlyGenerate():
    # варіанти чисел
    numbers = "0123456789"
    password = ""
    r = randrange(5, 13)
    for i in range(r):
        password += numbers[randrange(len(numbers))]
    return password

def passWithDateOnlyGenerate():
    # варіанти дат
    day = randrange(1,31)
    day = (f'{day}', f'{day:02}')[randrange(2)]
    month = randrange(1,13)
    month = (f'{month}', f'{month:02}')[randrange(2)]
    year = randrange(1921, 2021)
    year = (f'{year}', f'{year % 100:02}')[randrange(2)]
    r = randrange(6)
    if r == 0:
        password = f'{day}.{month}{year}'
    elif r == 1:
        password = f'{year}.{month}{day}'
    elif r == 2:
        password = f'{day}.{month}.{year}'
    elif r == 3:
        password = f'{year}.{month}.{day}'
    elif r == 4:
        password = f'{day}{month}{year}'
    else:
        password = f'{year}{month}{day}'
    return password

def replaceLettersWithNumbersInPass(password):
    # Заміна деяких букв цифрами
    replace = {
        'o': '0', 'e': '3', 's': '5', 'i': '1', 'g': '9',
        'O': '0', 'E': '3', 'S': '5', 'I': '1', 'B': '8', 'G': '6',
        'A': '4', '0': 'O', '5': 'S', '8': 'B', '9': 'g', '1': 'I', }
    result = ""
    for ch in password:
        if ch in replace and random() < 0.2:
            result += replace[ch]
        else:
            result += ch
    return result

def changeLetterRegisterInPass(password):
    # Заміна регістру букв
    r = randrange(5)
    if r == 0:
        result = password.upper()
    elif r == 1:
        result = password.lower()
    elif r == 2:
        result = ""
        for i in range(len(password)):
            if (random() < 0.5):
                if password[i].islower():
                    result += password[i].upper()
                else:
                    result += password[i].lower()
    elif r == 3:
        result = password.capitalize()
    elif r == 4:
        result = password
    return result

def passRandomGenerate():
    # варіанти випадкового паролю
    SOURCE = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789_!."
    password = ""
    length = randrange(5, 13)
    for i in range(length):
        password += SOURCE[randrange(len(SOURCE))]
    return password

def selectRandomPassFromTop(fromTop):
    # вибір випадкового паролю з списку
    return fromTop[randrange(len(fromTop))]

# %%
Counter({2: 59936, 4: 25062, 3: 9971, 1: 5031})
# Out:
# Counter({2: 59936, 4: 25062, 3: 9971, 1: 5031})

# %%
txt = Path('Files/Passwords.txt').read_text()
passWords = txt.split()
passWords1 = txt.splitlines()
print(f'{len(passWords) = }, зайвих: {len(passWords) - len(set(passWords))}\n', 
    sorted([x for x in Counter(passWords).items() if x[1] > 1], key=lambda x: x[1], reverse=True))
print(set(passWords1) - set(passWords))
# Out:
# len(passWords) = 100000, зайвих: 0
#  []
# set()

# %%
def PassGenerate():
    # генерування 100000 паролів різними способами
    passwords = set()
    indexes = {1:5, 2:60, 3:10, 4:25}
    max_rand = sum(indexes.values())
    tmp = 0
    porogs = [tmp := tmp + v for k, v in sorted(indexes.items())]    
    while len(passwords) < 100000:
        passTypeInd = randrange(max_rand) 
        for versionPass, v in enumerate(porogs, 1):
            if passTypeInd < v:
                break
        if versionPass == 1:
            password = passRandomGenerate()
        elif versionPass == 2:
            password = selectRandomPassFromTop(top1mWords)
        elif versionPass == 3:
            password = selectRandomPassFromTop(top100Words)
        else:
            password = humanLikePassGenerate()
        password and passwords.add(password)
    Path('outFiles/Passwords.txt').write_text('\n'.join(passwords))

PassGenerate()

# %%
indexes = {1:5, 2:60, 3:10, 4:25}
max_rand = sum(indexes.values())
print(max_rand)
tmp = 0
porogs = [tmp := tmp + v for k, v in sorted(indexes.items())] 
porogs
